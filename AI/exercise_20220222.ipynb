# %%
x = np.linspace(0, 5, 50)

# %%
y = 1.2 * x + 0.8

# %%
plt.scatter(x,y)
plt.plot(x, y, 'r')

# %%
y = 1.2 * x + 0.8 + 0.6 * np.random.randn(50)

# %%
plt.scatter(x, y)
plt.plot(x, 1.2 * x + 0.8, 'r')

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
y
# Out:
# array([0.82279022, 1.58277453, 1.36643915, 1.78582445, 1.58507286,
#        1.70274914, 1.77398956, 1.88661705, 1.61901613, 1.72602954,
#        2.02957506, 1.80835854, 2.60727537, 1.3016595 , 2.49698621,
#        2.58362146, 2.92617938, 3.55032322, 3.10754013, 4.36696408,
#        2.22142603, 3.65777734, 3.65302808, 2.56786623, 4.18518329,
#        3.36798108, 2.81217627, 3.59623039, 5.51876129, 4.7060739 ,
#        4.10230553, 3.91147661, 4.68148197, 4.75211383, 4.53110886,
#        5.78396805, 5.65665976, 5.34540836, 4.9102234 , 6.3473335 ,
#        5.26455183, 5.36244047, 4.86651138, 5.9919134 , 6.7390144 ,
#        6.28716006, 5.82317138, 5.68097922, 5.72009992, 6.64143155])

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()

# %%
X = x.reshape(50,1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, Y, 'r')
plt.plot(x, 1.2*x+0.8, 'g')
